# %%
# !qi login "https://api.quantum-inspire.com"

# %%
import numpy as np
from qiskit import QuantumCircuit, transpile
from qiskit_quantuminspire.qi_provider import QIProvider
import matplotlib.pyplot as plt
from utility_functions import return_raw_data, get_raw_data_counts, get_raw_data_prob
from scipy.optimize import curve_fit

# %%
provider = QIProvider()

# %%
provider.backends()

# %%
backend_name = "Starmon-7"
backend = provider.get_backend(name=backend_name)

# %%
backend.coupling_map.draw()

# %%
# %matplotlib inline
# %run GHZ_test.py
# Out:
# GHZ Circuit:
#      ┌───┐          ┌─┐
# q_0: ┤ H ├──■───────┤M├──────────────────────────────────────
#      └───┘┌─┴─┐     └╥┘     ┌─┐
# q_1: ─────┤ X ├──■───╫──────┤M├──────────────────────────────
#           └───┘┌─┴─┐ ║      └╥┘     ┌─┐
# q_2: ──────────┤ X ├─╫───■───╫──────┤M├──────────────────────
#                └───┘ ║ ┌─┴─┐ ║      └╥┘     ┌─┐
# q_3: ────────────────╫─┤ X ├─╫───■───╫──────┤M├──────────────
#                      ║ └───┘ ║ ┌─┴─┐ ║      └╥┘     ┌─┐
# q_4: ────────────────╫───────╫─┤ X ├─╫───■───╫──────┤M├──────
#                      ║       ║ └───┘ ║ ┌─┴─┐ ║      └╥┘┌─┐
# q_5: ────────────────╫───────╫───────╫─┤ X ├─╫───■───╫─┤M├───
#                      ║       ║       ║ └───┘ ║ ┌─┴─┐ ║ └╥┘┌─┐
# q_6: ────────────────╫───────╫───────╫───────╫─┤ X ├─╫──╫─┤M├
#                      ║       ║       ║       ║ └───┘ ║  ║ └╥┘
# c: 7/════════════════╩═══════╩═══════╩═══════╩═══════╩══╩══╩═
#                      0       1       2       3       4  5  6
# ---------------------------------------------------------------------------
# JobTimeoutError                           Traceback (most recent call last)
# File ~\GHZ_test.py:27
#      25 transpiled_qc = transpile(qc, backend=backend)
#      26 job = backend.run(transpiled_qc, shots=1024)
# ---> 27 result = job.result()
#      28 counts = result.get_counts()
#      30 # Print probabilities for each state
#
# File ~\miniconda3\envs\quantuminspire\Lib\site-packages\qiskit_quantuminspire\qi_jobs.py:456, in QIJob.result(self, wait_for_results, timeout)
#     454 """Return the results of the job."""
#     455 if wait_for_results:
# --> 456     self.wait_for_final_state(timeout=timeout)
#     457 elif not self.done():
#     458     raise RuntimeError(f"(Batch)Job status is {self.status()}.")
#
# File ~\miniconda3\envs\quantuminspire\Lib\site-packages\qiskit\providers\job.py:123, in JobV1.wait_for_final_state(self, timeout, wait, callback)
#     121 elapsed_time = time.time() - start_time
#     122 if timeout is not None and elapsed_time >= timeout:
# --> 123     raise JobTimeoutError(f"Timeout while waiting for job {self.job_id()}.")
#     124 if callback:
#     125     callback(self.job_id(), status, self)
#
# JobTimeoutError: 'Timeout while waiting for job .'
